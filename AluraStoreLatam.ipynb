# %% [markdown]
# <a href="https://colab.research.google.com/github/gaboitec/Challenge-AluraStore-ONE/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ventas_tienda1 = tienda1["Precio"].sum()
print(ventas_tienda1)
# Out:
# 1150880400.0

# %%
ventas_tienda2 = tienda2["Precio"].sum()
print(ventas_tienda2)
# Out:
# 1116343500.0

# %%
ventas_tienda3 = tienda3["Precio"].sum()
print(ventas_tienda2)
# Out:
# 1116343500.0

# %%
ventas_tienda4 = tienda4["Precio"].sum()
print(ventas_tienda2)
# Out:
# 1116343500.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda1['Categoría del Producto']
# Out:
# 0            Electrónicos
# 1                 Muebles
# 2                Juguetes
# 3       Electrodomésticos
# 4                 Muebles
#               ...
# 2354         Electrónicos
# 2355         Electrónicos
# 2356             Juguetes
# 2357              Muebles
# 2358         Electrónicos
# Name: Categoría del Producto, Length: 2359, dtype: object

# %%
tienda1[['Categoría del Producto','Producto']]
# Out:
#      Categoría del Producto           Producto
# 0              Electrónicos  Asistente virtual
# 1                   Muebles    Mesa de comedor
# 2                  Juguetes      Juego de mesa
# 3         Electrodomésticos         Microondas
# 4                   Muebles   Silla de oficina
# ...                     ...                ...
# 2354           Electrónicos          Iphone 15
# 2355           Electrónicos          Impresora
# 2356               Juguetes      Juego de mesa
# 2357                Muebles           Cama box
# 2358           Electrónicos         Smartwatch
#
# [2359 rows x 2 columns]

# %%
tienda1.groupby('Categoría del Producto').count()
# Out:
#                          Producto  Precio  Costo de envío  Fecha de Compra  \
# Categoría del Producto
# Artículos para el hogar       171     171             171              171
# Deportes y diversión          284     284             284              284
# Electrodomésticos             312     312             312              312
# Electrónicos                  448     448             448              448
# Instrumentos musicales        182     182             182              182
# Juguetes                      324     324             324              324
# Libros                        173     173             173              173
# Muebles                       465     465             465              465
#
#                          Vendedor  Lugar de Compra  Calificación  \
# Categoría del Producto
# Artículos para el hogar       171              171           171
# Deportes y diversión          284              284           284
# ...

# %%
tienda1.groupby('Categoría del Producto').count()['Producto']
# Out:
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# Name: Producto, dtype: int64

# %%
tienda1.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda1.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Producto, dtype: int64

# %%
tienda2.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Producto, dtype: int64

# %%
tienda3.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# Instrumentos musicales     177
# Name: Producto, dtype: int64

# %%
tienda4.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: Producto, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
tienda1.groupby('Calificación').count()
# Out:
#               Producto  Categoría del Producto  Precio  Costo de envío  \
# Calificación
# 1                  319                     319     319             319
# 2                   86                      86      86              86
# 3                  218                     218     218             218
# 4                  444                     444     444             444
# 5                 1292                    1292    1292            1292
#
#               Fecha de Compra  Vendedor  Lugar de Compra  Método de pago  \
# Calificación
# 1                         319       319              319             319
# 2                          86        86               86              86
# 3                         218       218              218             218
# 4                         444       444              444             444
# 5                        1292      1292             1292            1292
#
#               Cantidad de cuotas   lat   lon
# Calificación
# ...

# %%
tienda1.groupby('Producto')['Calificación'].mean()
# Out:
# Producto
# Ajedrez de madera              4.428571
# Armario                        3.950000
# Asistente virtual              4.075000
# Auriculares                    3.640000
# Auriculares con micrófono      3.969697
# Balón de baloncesto            3.872727
# Balón de voleibol              4.071429
# Batería                        4.188679
# Bicicleta                      3.944444
# Bloques de construcción        4.089286
# Cama box                       4.113636
# Cama king                      3.772727
# Carrito de control remoto      4.134615
# Celular ABXY                   3.818182
# Ciencia de datos con Python    4.102564
# Cubertería                     4.230769
# Cubo mágico 8x8                4.068182
# Cuerda para saltar             3.625000
# Dashboards con Power BI        3.952381
# Dinosaurio Rex                 3.775000
# Estufa                         4.133333
# Guitarra acústica              3.956522
# Guitarra eléctrica             4.085106
# ...

# %%
tienda1.groupby('Producto')['Calificación'].mean().round(1)
# Out:
# Producto
# Ajedrez de madera              4.4
# Armario                        4.0
# Asistente virtual              4.1
# Auriculares                    3.6
# Auriculares con micrófono      4.0
# Balón de baloncesto            3.9
# Balón de voleibol              4.1
# Batería                        4.2
# Bicicleta                      3.9
# Bloques de construcción        4.1
# Cama box                       4.1
# Cama king                      3.8
# Carrito de control remoto      4.1
# Celular ABXY                   3.8
# Ciencia de datos con Python    4.1
# Cubertería                     4.2
# Cubo mágico 8x8                4.1
# Cuerda para saltar             3.6
# Dashboards con Power BI        4.0
# Dinosaurio Rex                 3.8
# Estufa                         4.1
# Guitarra acústica              4.0
# Guitarra eléctrica             4.1
# Impresora                      4.2
# Iniciando en programación      4.3
# Iphone 15                      3.9
# ...

# %%
tienda2.groupby('Producto')['Calificación'].mean().round(1)
# Out:
# Producto
# Ajedrez de madera              4.1
# Armario                        3.9
# Asistente virtual              3.8
# Auriculares                    3.8
# Auriculares con micrófono      3.9
# Balón de baloncesto            4.1
# Balón de voleibol              3.8
# Batería                        4.0
# Bicicleta                      4.5
# Bloques de construcción        4.3
# Cama box                       4.1
# Cama king                      4.4
# Carrito de control remoto      4.1
# Celular ABXY                   4.0
# Ciencia de datos con Python    3.8
# Cubertería                     3.6
# Cubo mágico 8x8                3.6
# Cuerda para saltar             4.0
# Dashboards con Power BI        4.0
# Dinosaurio Rex                 4.3
# Estufa                         4.0
# Guitarra acústica              4.0
# Guitarra eléctrica             3.9
# Impresora                      4.4
# Iniciando en programación      4.0
# Iphone 15                      3.8
# ...

# %%
tienda3.groupby('Producto')['Calificación'].mean().round(1)
# Out:
# Producto
# Ajedrez de madera              3.9
# Armario                        4.1
# Asistente virtual              3.7
# Auriculares                    4.0
# Auriculares con micrófono      3.8
# Balón de baloncesto            4.0
# Balón de voleibol              3.7
# Batería                        4.0
# Bicicleta                      3.8
# Bloques de construcción        4.3
# Cama box                       3.9
# Cama king                      4.0
# Carrito de control remoto      4.2
# Celular ABXY                   4.4
# Ciencia de datos con Python    4.0
# Cubertería                     3.9
# Cubo mágico 8x8                4.2
# Cuerda para saltar             3.9
# Dashboards con Power BI        4.4
# Dinosaurio Rex                 4.1
# Estufa                         4.2
# Guitarra acústica              3.9
# Guitarra eléctrica             4.1
# Impresora                      4.4
# Iniciando en programación      4.1
# Iphone 15                      4.0
# ...

# %%
tienda4.groupby('Producto')['Calificación'].mean().round(1)
# Out:
# Producto
# Ajedrez de madera              4.0
# Armario                        4.2
# Asistente virtual              4.0
# Auriculares                    4.3
# Auriculares con micrófono      4.0
# Balón de baloncesto            3.9
# Balón de voleibol              4.3
# Batería                        4.3
# Bicicleta                      3.9
# Bloques de construcción        3.8
# Cama box                       4.0
# Cama king                      3.9
# Carrito de control remoto      3.9
# Celular ABXY                   3.9
# Ciencia de datos con Python    3.8
# Cubertería                     4.0
# Cubo mágico 8x8                3.9
# Cuerda para saltar             4.3
# Dashboards con Power BI        4.0
# Dinosaurio Rex                 4.0
# Estufa                         3.8
# Guitarra acústica              3.7
# Guitarra eléctrica             3.8
# Impresora                      4.1
# Iniciando en programación      4.3
# Iphone 15                      4.1
# ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
tienda1.groupby('Producto')['Producto'].count().sort_values(ascending=False).head()
# Out:
# Producto
# Armario             60
# TV LED UHD 4K       60
# Microondas          60
# Secadora de ropa    58
# Mesa de noche       56
# Name: Producto, dtype: int64

# %%
tienda1.groupby('Producto')['Producto'].count().sort_values().head()
# Out:
# Producto
# Auriculares con micrófono      33
# Celular ABXY                   33
# Olla de presión                35
# Pandereta                      36
# Ciencia de datos con Python    39
# Name: Producto, dtype: int64

# %%
tienda2.groupby('Producto')['Producto'].count().sort_values(ascending=False).head()
# Out:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Pandereta                    58
# Guitarra acústica            58
# Name: Producto, dtype: int64

# %%
tienda2.groupby('Producto')['Producto'].count().sort_values().head()
# Out:
# Producto
# Juego de mesa      32
# Impresora          34
# Mesa de comedor    34
# Sillón             35
# Auriculares        37
# Name: Producto, dtype: int64

# %%
tienda3.groupby('Producto')['Producto'].count().sort_values(ascending=False).head()
# Out:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: Producto, dtype: int64

# %%
tienda3.groupby('Producto')['Producto'].count().sort_values().head()
# Out:
# Producto
# Bloques de construcción    35
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Vaso térmico               38
# Name: Producto, dtype: int64

# %%
tienda4.groupby('Producto')['Producto'].count().sort_values(ascending=False).head()
# Out:
# Producto
# Cama box                     62
# Cubertería                   59
# Cama king                    56
# Dashboards con Power BI      56
# Carrito de control remoto    55
# Name: Producto, dtype: int64

# %%
tienda4.groupby('Producto')['Producto'].count().sort_values().head()
# Out:
# Producto
# Guitarra eléctrica             33
# Armario                        34
# Guitarra acústica              37
# Ciencia de datos con Python    38
# Lavadora de ropa               38
# Name: Producto, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
tienda1[['Producto','Costo de envío']].sort_values('Producto')
# Out:
#                Producto  Costo de envío
# 1227  Ajedrez de madera          1500.0
# 1918  Ajedrez de madera          2500.0
# 1917  Ajedrez de madera             0.0
# 1892  Ajedrez de madera          6500.0
# 691   Ajedrez de madera          2200.0
# ...                 ...             ...
# 2038       Vaso térmico          2800.0
# 641        Vaso térmico          5500.0
# 2023       Vaso térmico          2700.0
# 698        Vaso térmico             0.0
# 536        Vaso térmico           800.0
#
# [2359 rows x 2 columns]

# %%
tienda1.groupby('Producto')['Costo de envío'].mean().round(1)
# Out:
# Producto
# Ajedrez de madera                1691.8
# Armario                         26068.3
# Asistente virtual               10620.0
# Auriculares                      5694.0
# Auriculares con micrófono        8221.2
# Balón de baloncesto              2560.0
# Balón de voleibol                2440.5
# Batería                         37956.6
# Bicicleta                       26827.8
# Bloques de construcción          1644.6
# Cama box                        26277.3
# Cama king                       37884.1
# Carrito de control remoto        3655.8
# Celular ABXY                    52954.5
# Ciencia de datos con Python      2705.1
# Cubertería                       2051.9
# Cubo mágico 8x8                   911.4
# Cuerda para saltar               2065.0
# Dashboards con Power BI          2040.5
# Dinosaurio Rex                   1740.0
# Estufa                          35204.4
# Guitarra acústica               16276.1
# Guitarra eléctrica              42534.0
# ...

# %%
tienda1['Costo de envío'].mean().round(2)
# Out:
# np.float64(26018.61)

# %%
tienda2['Costo de envío'].mean().round(2)
# Out:
# np.float64(25216.24)

# %%
tienda3['Costo de envío'].mean().round(2)
# Out:
# np.float64(24805.68)

# %%
tienda4['Costo de envío'].mean().round(2)
# Out:
# np.float64(23459.46)

# %% [markdown]
# #Visualización

# %%
ventas_por_cat_t1 = tienda1.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
ventas_por_cat_t1.plot(title='Porcentaje de ventas por categoría Tienda 1', kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Porcentaje de ventas por categoría Tienda 1'}, ylabel='Producto'>

# %%
cal_promedio_t2 = tienda2.groupby('Producto')['Calificación'].mean().round(1).sort_values()
cal_promedio_t2.plot(title='Calificación promedio por producto Tienda 2', kind='barh', figsize=(4,10), color='green')
# Out:
# <Axes: title={'center': 'Calificación promedio por producto Tienda 2'}, ylabel='Producto'>

# %%
prod_mas_vendidos_t3 = tienda3.groupby('Categoría del Producto')['Producto'].count().head(10)
prod_mas_vendidos_t3.plot(title='Productos más vendidos Tienda 3', kind='bar', figsize=(10,5))
# Out:
# <Axes: title={'center': 'Productos más vendidos Tienda 3'}, xlabel='Categoría del Producto'>

# %% [markdown]
# # Informe Final
# De acuerdo con el análisis anterior sobre el rendimiento de cada tienda de la línea Alura Store, se llegó a una conclusión sobre cuál debería ser la respectiva tienda que debería, por motivos de rendimiento, ser vendida como acción contra sus respectivos resultados.
#
# Se llegó a la conclusión que, la tienda que debería ser vendida es la Tienda No. 2. Esto debido a que, en primer lugar, las ventas máximas de cada categoría, la tienda No. 2 tiene el puntaje dentro de la categoría "muebles" el cual es la categoría de mayor ventas de las 4 tiendas, siendo ésta la que posee el valor más bajo.
# Además, la tienda No. 2 es la menos puntaje alto posee en respecto a la calificación promedio por producto, en el mismo producto de las 4 tiendas.
